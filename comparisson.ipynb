# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.family'] = 'Arial'
#increase font size of plots
plt.rcParams.update({'font.size': 16})
# Data setup
specimens = [
    "3-Axis Plastic 2.22",
    "3-Axis Plastic 1.04",
    "5-Axis Plastic 2.22",
    "5-Axis Plastic 2.22 (Best 5)"
]

# Values for each property (ensure all lists match the length of `specimens`)
# Values for each property
flexural_modulus = [39640.04, 41075.14, 38806.33, 46678.34]
flexural_strength = [268.78 , 248.71, 389.14, 458.98]
max_flexural_strain = [None, 0.01952, 0.02, 0.018]

compression_modulus = [61933.37, 76226.84, 55288.6, 48934.16]
compression_strength = [216.69, 123.96, 175.13, 209.69]
ilss = [14.27, 11.42, 45.87, 22.23]

# Plot settings
x = np.arange(len(specimens))
width = 0.2

plt.rcParams['font.family'] = 'Arial'
# Increase font size of plots
plt.rcParams.update({'font.size': 14})

# Create separate plots for each property
fig, axs = plt.subplots(ncols=3, nrows=2, figsize=(15, 8))
fig.suptitle("Mechanical Properties of Specimens", fontsize=16)

# Plot for Flexural Modulus
axs[0, 0].bar(x, [v if v is not None else 0 for v in flexural_modulus], color='steelblue')
axs[0, 0].set_ylabel("Flexural Modulus (MPa)")
axs[0, 0].set_xticks(x)
axs[0, 0].set_xticklabels(specimens, rotation=15)

# Plot for Flexural Strength
axs[0, 1].bar(x, [v if v is not None else 0 for v in flexural_strength], color='darkorange')
axs[0, 1].set_ylabel("Flexural Strength (MPa)")
axs[0, 1].set_xticks(x)
axs[0, 1].set_xticklabels(specimens, rotation=15)

# # Plot for Maximum Flexural Strain
# axs[0, 2].bar(x, [v if v is not None else 0 for v in max_flexural_strain], color='seagreen')
# axs[0, 2].set_ylabel("Max Flexural Strain")
# axs[0, 2].set_xticks(x)
# axs[0, 2].set_xticklabels(specimens, rotation=15)

# Plot for Compression Modulus
axs[1, 0].bar(x, [v if v is not None else 0 for v in compression_modulus], color='indigo')
axs[1, 0].set_ylabel("Compression Modulus (MPa)")
axs[1, 0].set_xticks(x)
axs[1, 0].set_xticklabels(specimens, rotation=15)

# Plot for Compression Strength
axs[1, 1].bar(x, [v if v is not None else 0 for v in compression_strength], color='crimson')
axs[1, 1].set_ylabel("Compression Strength (MPa)")
axs[1, 1].set_xticks(x)
axs[1, 1].set_xticklabels(specimens, rotation=15)

# Plot for ILSS
axs[1, 2].bar(x, [v if v is not None else 0 for v in ilss], color='gray')
axs[1, 2].set_ylabel("ILSS (MPa)")
axs[1, 2].set_xticks(x)
axs[1, 2].set_xticklabels(specimens, rotation=15)

plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] = 'Arial'
# Increase font size of plots
plt.rcParams.update({'font.size': 20})

# Data setup
specimens = [
    "3-Axis ",
    "5-Axis "
]

# Values for each property
flexural_modulus = [39640.04, 46678.34]
flexural_strength = [268.78, 458.98]
compression_modulus = [61933.37, 48934.16]
compression_strength = [216.69, 209.69]
ilss = [14.27, 14.92]

# Plot settings
x = np.arange(len(specimens))
width = 0.2

# Create separate plots for each property
fig, axs = plt.subplots(ncols=3, nrows=2, figsize=(15, 10))
# Remove the unused plot in the upper row
fig.delaxes(axs[0, 2])

# Plot for Flexural Modulus
axs[0, 0].bar(x, [v if v is not None else 0 for v in flexural_modulus], color='steelblue')
axs[0, 0].set_ylabel("Flexural Modulus (MPa)")
axs[0, 0].set_xticks(x)
axs[0, 0].set_xticklabels(specimens, rotation=0)

# Plot for Flexural Strength
axs[0, 1].bar(x, [v if v is not None else 0 for v in flexural_strength], color='darkorange')
axs[0, 1].set_ylabel("Flexural Strength (MPa)")
axs[0, 1].set_xticks(x)
axs[0, 1].set_xticklabels(specimens, rotation=0)

# Plot for Compression Modulus
axs[1, 0].bar(x, compression_modulus, color='indigo')
axs[1, 0].set_ylabel("Compression Modulus (MPa)")
axs[1, 0].set_xticks(x)
axs[1, 0].set_xticklabels(specimens, rotation=0)

# Plot for Compression Strength
axs[1, 1].bar(x, compression_strength, color='crimson')
axs[1, 1].set_ylabel("Compression Strength (MPa)")
axs[1, 1].set_xticks(x)
axs[1, 1].set_xticklabels(specimens, rotation=0)

# Plot for ILSS
axs[1, 2].bar(x, ilss, color='gray')
axs[1, 2].set_ylabel("ILSS (MPa)")
axs[1, 2].set_xticks(x)
axs[1, 2].set_xticklabels(specimens, rotation=0)

plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] = 'Arial'
# Increase font size of plots
plt.rcParams.update({'font.size': 20})

# Data setup
specimens = [
    "3-Axis ",
    "5-Axis "
]

# Values for each property
flexural_modulus = [39640.04, 46678.34]
flexural_strength = [268.78, 458.98]
compression_modulus = [61933.37, 48934.16]
compression_strength = [216.69, 209.69]
ilss = [14.27, 14.92]

# Calculate percentage change for each property
# Corrected calculation for percentage change
# Calculate percentage change for each property
flexural_modulus_change = [100 * (flexural_modulus[1] - flexural_modulus[0]) / flexural_modulus[0]]
flexural_strength_change = [100 * (flexural_strength[1] - flexural_strength[0]) / flexural_strength[0]]
compression_modulus_change = [100 * (compression_modulus[1] - compression_modulus[0]) / compression_modulus[0]]
compression_strength_change = [100 * (compression_strength[1] - compression_strength[0]) / compression_strength[0]]
ilss_change = [100 * (ilss[1] - ilss[0]) / ilss[0]]

# Plot settings
x = np.arange(len(specimens))
width = 0.6

# Create separate plots for each property
fig, axs = plt.subplots(ncols=3, nrows=2, figsize=(15, 10))
# Remove the unused plot in the upper row
fig.delaxes(axs[0, 2])

# Function to add percentage change text above bars
def add_percentage_text(ax, values, percent_changes):
    for i, (value, percent_change) in enumerate(zip(values, percent_changes)):
        ax.text(i, value + max(values) * 0.02, f"{percent_change:.1f}%", 
                ha='center', fontsize=14, color='red' if i == 1 else 'blue')

# Plot for Flexural Modulus
axs[0, 0].bar(x, flexural_modulus, color=['blue', 'red'], width=width)
axs[0, 0].set_ylabel("Flexural Modulus (MPa)")
axs[0, 0].set_xticks(x)
axs[0, 0].set_xticklabels(specimens, rotation=0)
add_percentage_text(axs[0, 0], flexural_modulus, flexural_modulus_change)

# Plot for Flexural Strength
axs[0, 1].bar(x, flexural_strength, color=['blue', 'red'], width=width)
axs[0, 1].set_ylabel("Flexural Strength (MPa)")
axs[0, 1].set_xticks(x)
axs[0, 1].set_xticklabels(specimens, rotation=0)
add_percentage_text(axs[0, 1], flexural_strength, flexural_strength_change)

# Plot for Compression Modulus
axs[1, 0].bar(x, compression_modulus, color=['blue', 'red'], width=width)
axs[1, 0].set_ylabel("Compression Modulus (MPa)")
axs[1, 0].set_xticks(x)
axs[1, 0].set_xticklabels(specimens, rotation=0)
add_percentage_text(axs[1, 0], compression_modulus, compression_modulus_change)

# Plot for Compression Strength
axs[1, 1].bar(x, compression_strength, color=['blue', 'red'], width=width)
axs[1, 1].set_ylabel("Compression Strength (MPa)")
axs[1, 1].set_xticks(x)
axs[1, 1].set_xticklabels(specimens, rotation=0)
add_percentage_text(axs[1, 1], compression_strength, compression_strength_change)

# Plot for ILSS
axs[1, 2].bar(x, ilss, color=['blue', 'red'], width=width)
axs[1, 2].set_ylabel("ILSS (MPa)")
axs[1, 2].set_xticks(x)
axs[1, 2].set_xticklabels(specimens, rotation=0)
add_percentage_text(axs[1, 2], ilss, ilss_change)

plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.show()

# %% [markdown]
# # v3

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] = 'Arial'
# Increase font size of plots
plt.rcParams.update({'font.size': 30})

# Data setup
specimens = [
    "3-Axis ",
    "5-Axis "
]

# Values for each property
flexural_modulus = [39640.04, 46678.34]
flexural_strength = [268.78, 458.98]
compression_modulus = [61933.37, 48934.16]
compression_strength = [216.69, 209.69]
ilss = [14.27, 14.92]

# Calculate percentage change for each property
flexural_modulus_change = [100 * (flexural_modulus[1] - flexural_modulus[0]) / flexural_modulus[0]]
flexural_strength_change = [100 * (flexural_strength[1] - flexural_strength[0]) / flexural_strength[0]]
compression_modulus_change = [100 * (compression_modulus[1] - compression_modulus[0]) / compression_modulus[0]]
compression_strength_change = [100 * (compression_strength[1] - compression_strength[0]) / compression_strength[0]]
ilss_change = [100 * (ilss[1] - ilss[0]) / ilss[0]]

# Plot settings
x = np.arange(len(specimens))
width = 0.9

# Create separate plots for each property
fig, axs = plt.subplots(ncols=3, nrows=2, figsize=(24, 20))
# Remove the unused plot in the upper row
fig.delaxes(axs[0, 2])

plt.subplots_adjust(wspace=0, hspace=0) 

# Function to add percentage change text above bars
def add_percentage_text(ax, values, percent_change):
    for i, value in enumerate(values):
        if i == 1:  # Only add percentage change for "5-Axis"
            symbol = "+" if percent_change[0] > 0 else ""
            ax.text(i, value + max(values) * 0.02, f"{symbol}{percent_change[0]:.1f}%", 
                    ha='center', fontsize=33, color='red')

# Plot for Flexural Modulus
axs[0, 0].bar(x, flexural_modulus, color=['lightblue', 'lightcoral'], width=width)
axs[0, 0].set_ylabel("Flexural Modulus (MPa)")
axs[0, 0].set_xticks(x)
axs[0, 0].set_xticklabels(specimens, rotation=0)
add_percentage_text(axs[0, 0], flexural_modulus, flexural_modulus_change)

# Plot for Flexural Strength
axs[0, 1].bar(x, flexural_strength, color=['lightblue', 'lightcoral'], width=width)
axs[0, 1].set_ylabel("Flexural Strength (MPa)")
axs[0, 1].set_xticks(x)
axs[0, 1].set_xticklabels(specimens, rotation=0)
add_percentage_text(axs[0, 1], flexural_strength, flexural_strength_change)

# Plot for Compression Modulus
axs[1, 0].bar(x, compression_modulus, color=['lightblue', 'lightcoral'], width=width)
axs[1, 0].set_ylabel("Compression Modulus (MPa)")
axs[1, 0].set_xticks(x)
axs[1, 0].set_xticklabels(specimens, rotation=0)
add_percentage_text(axs[1, 0], compression_modulus, compression_modulus_change)

# Plot for Compression Strength
axs[1, 1].bar(x, compression_strength, color=['lightblue', 'lightcoral'], width=width)
axs[1, 1].set_ylabel("Compression Strength (MPa)")
axs[1, 1].set_xticks(x)
axs[1, 1].set_xticklabels(specimens, rotation=0)
add_percentage_text(axs[1, 1], compression_strength, compression_strength_change)

# Plot for ILSS
axs[1, 2].bar(x, ilss, color=['lightblue', 'lightcoral'], width=width)
axs[1, 2].set_ylabel("ILSS (MPa)")
axs[1, 2].set_xticks(x)
axs[1, 2].set_xticklabels(specimens, rotation=0)
add_percentage_text(axs[1, 2], ilss, ilss_change)

plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] = 'Arial'
# Increase font size of plots
plt.rcParams.update({'font.size': 30})

# Data setup
specimens = [
    "3-Axis ",
    "5-Axis "
]

# Values for each property
flexural_modulus = [39640.04, 46678.34]
flexural_strength = [268.78, 458.98]
compression_modulus = [61933.37, 48934.16]
compression_strength = [216.69, 209.69]
ilss = [14.27, 14.92]

# Calculate percentage change for each property
flexural_modulus_change = [100 * (flexural_modulus[1] - flexural_modulus[0]) / flexural_modulus[0]]
flexural_strength_change = [100 * (flexural_strength[1] - flexural_strength[0]) / flexural_strength[0]]
compression_modulus_change = [100 * (compression_modulus[1] - compression_modulus[0]) / compression_modulus[0]]
compression_strength_change = [100 * (compression_strength[1] - compression_strength[0]) / compression_strength[0]]
ilss_change = [100 * (ilss[1] - ilss[0]) / ilss[0]]

# Plot settings
x = np.arange(len(specimens))
width = 0.9

# Create separate plots for each property
fig, axs = plt.subplots(ncols=3, nrows=2, figsize=(24, 20))
# Remove the unused plot in the upper row
fig.delaxes(axs[0, 2])

plt.subplots_adjust(wspace=0, hspace=0) 

# Function to add percentage change text above bars
def add_percentage_text(ax, values, percent_change):
    for i, value in enumerate(values):
        if i == 1:  # Only add percentage change for "5-Axis"
            symbol = "+" if percent_change[0] > 0 else ""
            ax.text(i, value + max(values) * 0.02, f"{symbol}{percent_change[0]:.1f}%", 
                    ha='center', fontsize=33, color='red')

# Plot for Flexural Modulus
axs[0, 0].bar(x, flexural_modulus, color=['lightblue', 'lightcoral'], width=width)
axs[0, 0].set_ylabel("Flexural Modulus (MPa)")
axs[0, 0].set_xticks(x)
axs[0, 0].set_xticklabels(specimens, rotation=0)
add_percentage_text(axs[0, 0], flexural_modulus, flexural_modulus_change)


plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] = 'Arial'
# Increase font size of plots
plt.rcParams.update({'font.size': 30})

# Data setup
methods = [
    "INSTRON",
    "Timoshenko Beam",
    "Rule of mixtures"
]

# Values for each method
flexural_modulus_3_axis = [39640.04, 96717, 100900]
flexural_modulus_5_axis = [46678.34, 95878, 100900]

# Calculate percentage change for each method
flexural_modulus_change = [
    100 * (flexural_modulus_5_axis[i] - flexural_modulus_3_axis[i]) / flexural_modulus_3_axis[i]
    for i in range(len(methods))
]

# Plot settings
x = np.arange(len(methods))
width = 0.4  # Bar width

# Create the plot
fig, ax = plt.subplots(figsize=(18, 10))

# Plot bars for 3-axis and 5-axis
bars_3_axis = ax.bar(x - width / 2, flexural_modulus_3_axis, width, label="3-Axis", color='lightblue')#, edgecolor='grey')
bars_5_axis = ax.bar(x + width / 2, flexural_modulus_5_axis, width, label="5-Axis", color='lightcoral')#, edgecolor='grey')

# Add percentage change text above 5-axis bars
# for i, (bar, percent_change) in enumerate(zip(bars_5_axis, flexural_modulus_change)):
#     symbol = "+" if percent_change > 0 else ""
#     ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + max(flexural_modulus_3_axis) * 0.02,
#             f"{symbol}{percent_change:.1f}%", ha='center', fontsize=20, color='red')

# Add labels, title, and legend
ax.set_ylabel("Flexural Modulus (MPa)")
ax.set_xticks(x)
ax.set_xticklabels(methods, rotation=0)
ax.legend(fontsize=20)
# ax.set_title("Flexural Modulus Comparison", fontsize=35)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
